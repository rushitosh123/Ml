# %%
import pandas as pd

# %%
df = pd.read_csv(r"D:\overall_practice_Files\compux\train.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# 6 Questions ask once get the data set

# %%
# Q.1 How big is the data?      
df.shape
# Out:
# (891, 12)

# %%
# Q.2 How does the data look like?  
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass  \
# 333          334         0       3
# 95            96         0       3
# 448          449         1       3
# 85            86         1       3
# 233          234         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 333                    Vander Planke, Mr. Leo Edmondus    male  16.0      2
# 95                         Shorney, Mr. Charles Joseph    male   NaN      0
# 448                     Baclini, Miss. Marie Catherine  female   5.0      2
# 85   Backstrom, Mrs. Karl Alfred (Maria Mathilda Gu...  female  33.0      3
# 233                     Asplund, Miss. Lillian Gertrud  female   5.0      4
#
#      Parch   Ticket     Fare Cabin Embarked
# 333      0   345764  18.0000   NaN        S
# 95       0   374910   8.0500   NaN        S
# 448      1     2666  19.2583   NaN        C
# 85       0  3101278  15.8500   NaN        S
# 233      2   347077  31.3875   NaN        S

# %%
# Q.3 What is the data type of cols? 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# Q.4 Are there any missing values? 
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
# Q.5 How does the data look mathematically?
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# Q.6 Are there duplicate values? 
df.duplicated().sum()
# Out:
# 0

# %%
# Q.7 How is the correlation between cols? 
#df.corr()['Survived']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 2
#       1 # Q.7 How is the correlation between cols?
# ----> 2 df.corr()['Survived']
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
data = pd.get_dummies(df)
data

# %%
df['Survived'] = pd.to_numeric(df['Survived'], errors='coerce')

# %% [markdown]
# FOCUS ON UNIVARIATE ANALYSIS

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts()
# Out:
# Survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
df['Survived'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(x='Pclass', hue='Survived', data=df)
plt.title('Survived by Pclass')
plt.show()

# %%
# Pie chart 
df['Sex'].value_counts().plot(kind='pie',autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# # Numerical Data  columnn

# %%
#A. Histogram
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %%
# B. Distplot
sns.distplot(df['Age'])
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_18488\1787732654.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
#  c. Boxplot
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].max()
# Out:
# 80.0

# %%
df['Age'].mean()
# Out:
# 29.69911764705882

# %%
df['Age'].skew()
# Out:
# 0.38910778230082704

# %% [markdown]
# MULTI VARIATE ANALYSY

# %%
# Now we are using different datasets

# %%
import seaborn as sns

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# 1. Scatterplot (Numerical - Numerical) bi v
#sns.scatterplot(tips['total_bill'],tips['tip'])
sns.scatterplot(x='total_bill', y='tip', data=tips)
plt.show()

# %%
# 1. Scatterplot (Numerical - Numerical) multi variate
# sns.scatterplot(tips['total_bill'],tips['tip'],hue=df['sex'],style=df['smoker'],size=df['size'])
sns.scatterplot(x='total_bill', y='tip', hue='sex', style='smoker', size='size', data=tips)
plt.show()

# %% [markdown]
# # 2. Bar Plot (Numerical - Categorical)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# fidn avg age of different class
# x asis pe categorical feate and y axis pe numerical featere

# %%
sns.barplot(x = 'Pclass', y = 'Age', data = df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x = 'Pclass', y = 'Fare', data = df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Fare'>

# %%
#Bar Plot multi variate ananalys on 
#sns.barplot(titanic['Pclass'],titanic['Age'],hue=titanic['Sex'])
sns.barplot(x = 'Pclass', y = 'Age',hue='Sex', data = df)
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# # 3. Box Plot (Numerical - Categorical)

# %%
sns.boxplot(x = 'Sex',y = 'Age',data = df, hue='Survived')
# Out:
# <Axes: xlabel='Sex', ylabel='Age'>

# %%
df[['Sex','Age']]
# Out:
#         Sex   Age
# 0      male  22.0
# 1    female  38.0
# 2    female  26.0
# 3    female  35.0
# 4      male  35.0
# ..      ...   ...
# 886    male  27.0
# 887  female  19.0
# 888  female   NaN
# 889    male  26.0
# 890    male  32.0
#
# [891 rows x 2 columns]

# %% [markdown]
# # 4. Distplot (Numerical - Categorical)

# %%
sns.distplot(df[df['Survived']==0]['Age'])
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_18488\529285220.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(df[df['Survived']==0]['Age'],hist=False)
sns.distplot(df[df['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_18488\455601345.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df[df['Survived']==0]['Age'],hist=False)
# C:\Users\Hi\AppData\Local\Temp\ipykernel_18488\455601345.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
# ...

# %% [markdown]
# # 5. HeatMap (Categorical - Categorical)

# %%
#how many died or not diet
pd.crosstab(df['Pclass'],df['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(df['Pclass'],df['Survived']))
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
#df.groupby('Pclass').mean()['Survived']*100

# %%
#(df.groupby('Embarked').mean()['Survived']*100)

# %% [markdown]
# # 6. ClusterMap (Categorical - Categorical)

# %%
pd.crosstab(df['Parch'],df['Survived'])
# Out:
# Survived    0    1
# Parch
# 0         445  233
# 1          53   65
# 2          40   40
# 3           2    3
# 4           4    0
# 5           4    1
# 6           1    0

# %%
sns.clustermap(pd.crosstab(df['Parch'],df['Survived']))

# %% [markdown]
# # 7. Pairplot

# %%
# if we have multiple numerical columns

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue = 'species')

# %%
sns.pairplot(df)

# %% [markdown]
# # 8. Lineplot (Numerical - Numerical)

# %%
# if we have x axis quantity time base no yr,month. same as scaater plot
# covid no,

# %%
flights = sns.load_dataset('flights')
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
# yearwise how many passenger travel

# %%
flights_numeric = flights.select_dtypes(include=['number'])
flights_numeric.groupby('year').sum()
# Out:
#       passengers
# year
# 1949        1520
# 1950        1676
# 1951        2042
# 1952        2364
# 1953        2700
# 1954        2867
# 1955        3408
# 1956        3939
# 1957        4421
# 1958        4572
# 1959        5140
# 1960        5714

# %%
new = flights_numeric.groupby('year').sum().reset_index()
new
# Out:
#     year  passengers
# 0   1949        1520
# 1   1950        1676
# 2   1951        2042
# 3   1952        2364
# 4   1953        2700
# 5   1954        2867
# 6   1955        3408
# 7   1956        3939
# 8   1957        4421
# 9   1958        4572
# 10  1959        5140
# 11  1960        5714

# %%
sns.lineplot(x = 'year', y = 'passengers', data = new)
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(x='year', y='passengers', data=new)
plt.show()

# %%
flights
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
flights.pivot_table(values = 'passengers', index = 'month', columns = 'year')
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_18488\2751891872.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(values = 'passengers', index = 'month', columns = 'year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
sns.heatmap(flights.pivot_table(values = 'passengers', index = 'month', columns = 'year'))
# Out:
# C:\Users\Hi\AppData\Local\Temp\ipykernel_18488\3150123898.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values = 'passengers', index = 'month', columns = 'year'))
# <Axes: xlabel='year', ylabel='month'>

# %%
print('Hi')
# Out:
# Hi

# %%
a = [2,3,4,5,4,3,2,1,2,3,4,4,3,2,1,2,3,4,.,.,.,2,3,4,5,4,3,2,1,'apple', 'orange,mango']
b = ','
c = []
for i in a:
    if i != delimeter:
        
    i.split'.'
print(i, end = ' ')
# Out:
#   Cell In[276], line 1
#     a = [2,3,4,5,4,3,2,1,2,3,4,4,3,2,1,2,3,4,.,.,.,2,3,4,5,4,3,2,1]
#                                              ^
# SyntaxError: invalid syntax

# %%
plt.barplot(x ='Age',y = 'passengers', data = df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[286], line 1
# ----> 1 plt.barplot(x ='Age',y = 'passengers', data = df)
#
# AttributeError: module 'matplotlib.pyplot' has no attribute 'barplot'

# %%
import matplotlib.pyplot as plt
