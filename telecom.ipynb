# %%
import pandas as pd

# %%
df = pd.read_csv("D:\\overall_practice_Files\\Csv_files\\telecom.csv")

# %%
df
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9    64.0   4       5     0.0
# 1         3      11   33        1        7   136.0   5       5     0.0
# 2         3      68   52        1       24   116.0   1      29     0.0
# 3         2      33   33        0       12    33.0   2       0     0.0
# 4         2      23   30        1        9    30.0   1       2     0.0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0    27.0   3       0     0.0
# 996       1       7   34        0        2    22.0   5       5     0.0
# 997       3      67   59        0       40   944.0   5      33     0.0
# 998       3      70   49        0       18    87.0   2      22     0.0
# 999       3      50   36        1        7    39.0   3       3     0.0
#
#      gender  reside  custcat
# 0         0       2        1
# 1         0       6        4
# ...

# %%
df.tail()
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 995       3      10   39        0        0    27.0   3       0     0.0
# 996       1       7   34        0        2    22.0   5       5     0.0
# 997       3      67   59        0       40   944.0   5      33     0.0
# 998       3      70   49        0       18    87.0   2      22     0.0
# 999       3      50   36        1        7    39.0   3       3     0.0
#
#      gender  reside  custcat
# 995       1       3        1
# 996       1       1        1
# 997       1       1        4
# 998       1       1        3
# 999       1       3        2

# %%
df.head()
# Out:
#    region  tenure  age  marital  address  income  ed  employ  retire  gender  \
# 0       2      13   44        1        9    64.0   4       5     0.0       0
# 1       3      11   33        1        7   136.0   5       5     0.0       0
# 2       3      68   52        1       24   116.0   1      29     0.0       1
# 3       2      33   33        0       12    33.0   2       0     0.0       1
# 4       2      23   30        1        9    30.0   1       2     0.0       0
#
#    reside  custcat
# 0       2        1
# 1       6        4
# 2       2        3
# 3       1        1
# 4       4        3

# %%
df.describe()
# Out:
#           region       tenure          age      marital      address  \
# count  1000.0000  1000.000000  1000.000000  1000.000000  1000.000000
# mean      2.0220    35.526000    41.684000     0.495000    11.551000
# std       0.8162    21.359812    12.558816     0.500225    10.086681
# min       1.0000     1.000000    18.000000     0.000000     0.000000
# 25%       1.0000    17.000000    32.000000     0.000000     3.000000
# 50%       2.0000    34.000000    40.000000     0.000000     9.000000
# 75%       3.0000    54.000000    51.000000     1.000000    18.000000
# max       3.0000    72.000000    77.000000     1.000000    55.000000
#
#             income           ed       employ       retire       gender  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.000000
# mean     77.535000     2.671000    10.987000     0.047000     0.517000
# std     107.044165     1.222397    10.082087     0.211745     0.499961
# ...

# %%
df.shape
# Out:
# (1000, 12)

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['income'],df['age'], color = 'red', marker = 5)

# %%
df
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9    64.0   4       5     0.0
# 1         3      11   33        1        7   136.0   5       5     0.0
# 2         3      68   52        1       24   116.0   1      29     0.0
# 3         2      33   33        0       12    33.0   2       0     0.0
# 4         2      23   30        1        9    30.0   1       2     0.0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0    27.0   3       0     0.0
# 996       1       7   34        0        2    22.0   5       5     0.0
# 997       3      67   59        0       40   944.0   5      33     0.0
# 998       3      70   49        0       18    87.0   2      22     0.0
# 999       3      50   36        1        7    39.0   3       3     0.0
#
#      gender  reside  custcat
# 0         0       2        1
# 1         0       6        4
# ...

# %%
b = df.rename(columns={'age':'x','income':'Y'})

# %%
print(b)
# Out:
#      region  tenure   x  marital  address      Y  ed  employ  retire  gender  \
# 0         2      13  44        1        9   64.0   4       5     0.0       0
# 1         3      11  33        1        7  136.0   5       5     0.0       0
# 2         3      68  52        1       24  116.0   1      29     0.0       1
# 3         2      33  33        0       12   33.0   2       0     0.0       1
# 4         2      23  30        1        9   30.0   1       2     0.0       0
# ..      ...     ...  ..      ...      ...    ...  ..     ...     ...     ...
# 995       3      10  39        0        0   27.0   3       0     0.0       1
# 996       1       7  34        0        2   22.0   5       5     0.0       1
# 997       3      67  59        0       40  944.0   5      33     0.0       1
# 998       3      70  49        0       18   87.0   2      22     0.0       1
# 999       3      50  36        1        7   39.0   3       3     0.0       1
#
#      reside  custcat
# 0         2        1
# ...

# %%
df.rename(columns = {'age':'4', 'tenuere':'5'})
# Out:
#      region  tenure   4  marital  address  income  ed  employ  retire  gender  \
# 0         2      13  44        1        9    64.0   4       5     0.0       0
# 1         3      11  33        1        7   136.0   5       5     0.0       0
# 2         3      68  52        1       24   116.0   1      29     0.0       1
# 3         2      33  33        0       12    33.0   2       0     0.0       1
# 4         2      23  30        1        9    30.0   1       2     0.0       0
# ..      ...     ...  ..      ...      ...     ...  ..     ...     ...     ...
# 995       3      10  39        0        0    27.0   3       0     0.0       1
# 996       1       7  34        0        2    22.0   5       5     0.0       1
# 997       3      67  59        0       40   944.0   5      33     0.0       1
# 998       3      70  49        0       18    87.0   2      22     0.0       1
# 999       3      50  36        1        7    39.0   3       3     0.0       1
#
#      reside  custcat
# ...

# %%
df
# Out:
#      region  tenure  age  marital  address  income  ed  employ  retire  \
# 0         2      13   44        1        9    64.0   4       5     0.0
# 1         3      11   33        1        7   136.0   5       5     0.0
# 2         3      68   52        1       24   116.0   1      29     0.0
# 3         2      33   33        0       12    33.0   2       0     0.0
# 4         2      23   30        1        9    30.0   1       2     0.0
# ..      ...     ...  ...      ...      ...     ...  ..     ...     ...
# 995       3      10   39        0        0    27.0   3       0     0.0
# 996       1       7   34        0        2    22.0   5       5     0.0
# 997       3      67   59        0       40   944.0   5      33     0.0
# 998       3      70   49        0       18    87.0   2      22     0.0
# 999       3      50   36        1        7    39.0   3       3     0.0
#
#      gender  reside  custcat
# 0         0       2        1
# 1         0       6        4
# ...

# %%
import pandas as pd

# %%
house_pred = pd.read_csv('D:\\overall_practice_Files\\Csv_files\\bangalore house price prediction OHE-data.csv')
house_pred
# Out:
#       bath  balcony   price  total_sqft_int  bhk  price_per_sqft  \
# 0      3.0      2.0  150.00          1672.0    3     8971.291866
# 1      3.0      3.0  149.00          1750.0    3     8514.285714
# 2      3.0      2.0  150.00          1750.0    3     8571.428571
# 3      2.0      2.0   40.00          1250.0    2     3200.000000
# 4      2.0      2.0   83.00          1200.0    2     6916.666667
# ...    ...      ...     ...             ...  ...             ...
# 7115   3.0      2.0  325.00          2900.0    3    11206.896552
# 7116   3.0      1.0   84.83          1780.0    3     4765.730337
# 7117   2.0      1.0   48.00           880.0    2     5454.545455
# 7118   2.0      1.0   55.00          1000.0    2     5500.000000
# 7119   2.0      1.0   78.00          1400.0    3     5571.428571
#
#       area_typeSuper built-up  Area  area_typeBuilt-up  Area  \
# 0                                 1                        0
# ...

# %%
house_pred.isnull().sum()
# Out:
# bath                           0
# balcony                        0
# price                          0
# total_sqft_int                 0
# bhk                            0
#                               ..
# location_Hosur Road            0
# location_Horamavu Banaswadi    0
# location_Domlur                0
# location_Mahadevpura           0
# location_Tumkur Road           0
# Length: 108, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(house_pred['price'],house_pred['balcony'])

# %%
plt.bar(house_pred['price'],house_pred['balcony'])
# Out:
# <BarContainer object of 7120 artists>

# %%
X = house_pred.drop('price', axis = 1)
y = house_pred['price']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size = 0.2, random_state=51)

# %%
print('shape of X_train = ', X_train.shape)
print('shape of y_train = ', y_train.shape)
print('shape of X_test = ', X_test.shape)
print('shape of y_test = ', y_test.shape)
# Out:
# shape of X_train =  (5696, 107)
# shape of y_train =  (5696,)
# shape of X_test =  (1424, 107)
# shape of y_test =  (1424,)

# %%
# feature scaling
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = sc.transform(X_train)
X_test = sc.transform(X_test)

# %%
Linear Regression - ML Model Training
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

lr.fit(X_train, y_train)
LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)
lr.coef_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 X = df.drop('price', axis=1)
#       2 y = df['price']
#
# NameError: name 'df' is not defined
